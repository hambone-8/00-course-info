# %% [markdown]
# <html>
#     <div style="width:100%; float:left; background-color:#110D42; padding-top:10px; padding-bottom:10px">
#         <font color='white',size='6', face='Helvetica'><center>Capstone Project Template</center></font>
#     </div>
#     <div>
#         <ol><font size='4'>
#             <div style='float:left'>
#                 <li><a href="#Intro"><font color='black'><b>About the Author</b></font></a><br>
#                     <font size='3'>Want to learn about the person who did this project?</font></li>
#             <li><a href="#Overview"><font color='black'><b>Overview of Problem</b></font></a><br>
#                     <font size='3'>What are we trying to do?</font></li>
#             <li><a href="#Hypothesis"><font color='black'><b>Hypothesis</b></font></a><br>
#                     <font size='3'>What is the <i>question</i>?</font></li>
#             </div>
#             <div style='float:right'>
#             <li><a href="#Data"><font color='black'><b>Overview of Data Set</b></font></a><br>
#                     <font size='3'>Where did we get the data and why did we choose this data?</font></li>
#             <li><a href="#Methods"><font color='black'><b>Methodology</b></font></a><br>
#                     <font size='3'>How did we do what we did?</font></li>
#             <li><a href="#Conclusion"><font color='black'><b>Conclusion</b></font></a><br>
#                     <font size='3'>What does it all <i>mean</i>?</font></li>
#             </div>
#         </font></ol>
#     </div>
# </html>

# %% [markdown]
# <html>
#     <div style="width:100%; float:left; background-color:#110D42; padding-top:10px; padding-bottom:10px">
#         <a name="Intro"><font color='white',size='5.5', face='Helvetica'><center>About the Author</center></font></a>
#     </div>
#     <div>
#         <p><font size='4'>Kayla Vondy's inner soul is that of BearHat Man.</font></p>
#         <p><font size='4'>This is BearHat Man. BearHat Man likes to solve problems with code. BearHat Man doesn't care what you think because he is solving the world's problems while wearing his hat...that he made...from a bear.</font></p>
#         <img src="images/bearhatman.jpg">
#         <p><font size='4'>This is a komodo dragon. It is BearHat Man's spirit animal. It is a megafauna found in Indonesia. Wave back to the komodo dragon...it <i>is</i> a predator afterall, so make nice!</font></p>
#         <img src="images/komodo_dragon.jpg">
#     </div>
# </html>

# %% [markdown]
# <html>
#     <div style="width:100%; float:left; background-color:#110D42; padding-top:10px; padding-bottom:10px">
#         <a name="Overview"><font color='white',size='5.5', face='Helvetica'><center>The Problem</center></font></a>
#     </div>
#     <div>
#         <p><font size='4'>This is the problem...there is no problem. How does one even decide upon a problem to solve?</font></p>
#         <p><font size='4'> There are two main sites that contain datasets for such projects as these. They provide the datasets for coders like ourselves to be creative and find information that might be, if not beneficial then perhaps useful or at least interesting to the general public. </font></p>
#         <p><font size='4'>The first is <a href='https://www.pewresearch.org/download-datasets/'>Pew Research Center</a>, which contains data that they aggregate into topics such as: </font></p>
#         <div style="width:5%; float:left">&nbsp;</div>
#         <div style="width:30%; float:left">
#             <ul><li>U.S. Politics and Policy</li>
#                 <li>Journalism and Media</li>
#                 <li>Internet, Science and Tech</li>
#             </ul></div>
#         <div style="width:5%; float:left">&nbsp;</div>
#         <div style="width:30%; float:left">
#             <ul><li>Religion and Public Life</li>
#                 <li>Hispanic Trends</li>
#                 <li>Global Attitudes and Trends</li>
#             </ul></div>
#         <div style="width:5%; float:left">&nbsp;</div>
#         <div style="width:30%; float:left">
#             <ul>
#                 <li>Social and Demographic Trends</li>
#                 <li>American Trends Panel</li>
#                 <li>Methodology</li>
#             </ul></div>
#         <p>&nbsp;</p>
#         <p><font size='3'><i><center>"Pew Research Center is a nonpartisan fact tank that informs the public about the issues, attitudes and trends shaping the world. We conduct public opinion polling, demographic research, content analysis and other data-driven social science research. We do not take policy positions."</center></i></font><p>
#         <p><font size='4'>The second is <a href='https://www.kaggle.com/datasets'>Kaggle</a>, which has over 16,000 datasets that are tagged with keywords associating the datasets to topics such as:</font></p>
#         <div style="width:10%; float:left">&nbsp;</div>
#         <div style="width:20%; float:left">
#             <ul><li>Linguistics</li>
#                 <li>Sports</li>
#                 <li>Politics</li>
#             </ul></div>
#         <div style="width:10%; float:left">&nbsp;</div>
#         <div style="width:20%; float:left">
#             <ul><li>Demographics</li>
#                 <li>Business/Finance/Economics</li>
#                 <li>Image Data</li>
#             </ul></div>
#         <div style="width:10%; float:left">&nbsp;</div>
#         <div style="width:20%; float:left">
#             <ul>
#                 <li>Education</li>
#                 <li>History</li>
#                 <li>Animals</li>
#             </ul></div>
#         <div style="width:10%; float:left">&nbsp;</div>
#         <p>&nbsp;</p>
#         <p>&nbsp;</p>
#         <p><font size='3'><center><i>"Kaggle supports a variety of dataset publication formats, but we strongly encourage dataset publishers to share their data in an accessible, non-proprietary format if possible. Not only are open, accessible data formats better supported on the platform, they are also easier to work with for more people regardless of their tools."</i></center></font></p>
#     </div>
# </html>

# %% [markdown]
# <html>
#     <div style="width:30%; float:left; background-color:#110D42; padding-top:10px; padding-bottom:10px">
#         <a name="Hypothesis"><font color='white',size='5.5', face='Helvetica'><center>Hypothesis Addressed</center></font></a>
#     </div>
#     <div style="width:25px; float:left;">&nbsp;</div>
#     <div style="width:30%; float:left; background-color:#110D42; padding-top:10px; padding-bottom:10px">
#         <a name="Data"><font color='white',size='5.5', face='Helvetica'><center>The Data Set</center></font></a>
#     </div>
#     <div style="width:25px; float:left;">&nbsp;</div>
#     <div style="width:30%; float:left; background-color:#110D42; padding-top:10px; padding-bottom:10px">
#         <a name="Methods"><font color='white',size='5.5', face='Helvetica'><center>Methodology</center></font></a>
#     </div>
#     <div style="width:30%; float:left;">
#         <p><font size='3'>For this template, BearHat Man believes you will vote for him.</font></p>
#         <p><font size='3'>He is already the winner.</font></p>
#         <p><font size='3'>However, mere mortals will use this section to talk about the question they aim to research and answer via their analysis of their chosen dataset</font></p>
#     </div>
#     <div style="width:25px; float:left;">&nbsp;</div>
#     <div style="width:30%; float:left;">
#         <p><font size='3'>Umm BearHat Man has already scienced all the data. You do not need to find any more data. He has done it all. You can thank him later</font></p>
#         <p><font size='3'>But if you <i>want</i> to redo his work, you'd talk about your data here. Perhaps you'd like to talk about where you got your data, and why you chose this data.</font></p>
#     </div>
#     <div style="width:25px; float:left;">&nbsp;</div>
#     <div style="width:30%; float:left;">
#         <p><font size='3'>BearHat Man wants to know why you are questioning his methods. Do not worry about how he solved the problem, for the problem no longer exists...thanks to BearHat Man</font></p>
#         <p><font size='3'>Perhaps you'd like to talk about <i>how</i> you went about using the dataset to address your question/hypothesis.</font></p>
#     </div>
# </html>

# %% [markdown]
# <html>
#     <div style="width:100%; float:left; background-color:#110D42; padding-top:10px; padding-bottom:10px">
#         <a name="Conclusion"><font color='white',size='5.5', face='Helvetica'><center>Conclusion</center></font></a>
#     </div>
#     <div>
#         <p>&nbsp;</p>
#         <p><font size='8'><b><i><center>BearHat Man is the hero we all deserve.</center></i></b></font></p>
#         <p><font size='4'>Here we shall conclude what the data showed.</font></p>
#         <p><font size='4'>Perhaps we use visuals!</font></p>
#         <p><font size='4.5'>&nbsp;&nbsp;&nbsp;&nbsp; &nbsp;&nbsp;&nbsp;&nbsp; A word cloud?</font></p>
#         <p><font size='5'>&nbsp;&nbsp;&nbsp;&nbsp; &nbsp;&nbsp;&nbsp;&nbsp; &nbsp;&nbsp;&nbsp;&nbsp; A graph?</font></p>
#         <p><font size='5.5'>&nbsp;&nbsp;&nbsp;&nbsp; &nbsp;&nbsp;&nbsp;&nbsp; &nbsp;&nbsp;&nbsp;&nbsp; &nbsp;&nbsp;&nbsp;&nbsp; A chart?</font></p>
#         <p><font size='6'>&nbsp;&nbsp;&nbsp;&nbsp; &nbsp;&nbsp;&nbsp;&nbsp; &nbsp;&nbsp;&nbsp;&nbsp; &nbsp;&nbsp;&nbsp;&nbsp; &nbsp;&nbsp;&nbsp;&nbsp; A map?</font></p>
#         <p><font size='6.5'>&nbsp;&nbsp;&nbsp;&nbsp; &nbsp;&nbsp;&nbsp;&nbsp; &nbsp;&nbsp;&nbsp;&nbsp; &nbsp;&nbsp;&nbsp;&nbsp; &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; WHO KNOWS! The bounds are endless!</font></p>
#     </div>
# </html>
